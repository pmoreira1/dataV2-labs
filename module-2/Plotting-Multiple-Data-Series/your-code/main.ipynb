# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
total_bars = data.groupby("ItemType")[['RetailSales','RetailTransfers','WarehouseSales']].agg('sum')
total_bars.plot.bar()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
sales = data.groupby("Supplier")[['RetailSales','RetailTransfers','WarehouseSales']].agg('sum')
sales['TotalSales'] = sales['RetailSales'] + sales['WarehouseSales']
sales.sort_values(by='TotalSales', ascending=False, inplace=True)
sales.drop('TotalSales',axis=1, inplace=True)
sales[:10].plot.barh()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
multiline_avg = data.groupby(['Year','Month'])[['RetailSales','RetailTransfers','WarehouseSales']].agg('mean')
multiline_avg.plot()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
multiline_avg.plot.bar()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
multiline_sum = pd.pivot_table(data, columns=['ItemType'], values=['RetailSales'], index=['Year', 'Month'], aggfunc=np.sum)
multiline_sum.plot()

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
multiline_sum.plot.bar()

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
ax = sns.scatterplot(x='RetailSales',y='RetailTransfers',hue='ItemType',data=data)

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.pairplot(data=data[['RetailSales','RetailTransfers','WarehouseSales','Year','Month','ItemType']], hue='ItemType')
plt.show()

# %%
sns.pairplot(data=data, hue='ItemType')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-8dc30fac34ce> in <module>
# ----> 1 sns.pairplot(data=data, hue='ItemType')
#       2 plt.show()
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2119             diag_kws.setdefault("shade", True)
#    2120             diag_kws["legend"] = False
# -> 2121             grid.map_diag(kdeplot, **diag_kws)
#    2122
#    2123     # Maybe plot on the off-diagonals
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1488                     data_k = utils.remove_na(data_k)
#    1489
# -> 1490                 func(data_k, label=label_k, color=color, **kwargs)
#    1491
#    1492             self._clean_axis(ax)
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     701                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     702     else:
# --> 703         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     704                                  gridsize, cut, clip, legend, ax,
#     705                                  cumulative=cumulative, **kwargs)
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     291     elif _has_statsmodels:
#     292         # Prefer using statsmodels for kernel flexibility
# --> 293         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     294                                            gridsize, cut, clip,
#     295                                            cumulative=cumulative)
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     365     fft = kernel == "gau"
#     366     kde = smnp.KDEUnivariate(data)
# --> 367     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     368     if cumulative:
#     369         grid, y = kde.support, kde.cdf
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     136                 msg = "Weights are not implemented for fft"
#     137                 raise NotImplementedError(msg)
# --> 138             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     139                     adjust=adjust, weights=weights, gridsize=gridsize,
#     140                     clip=clip, cut=cut)
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     451         bw = float(bw)
#     452     except:
# --> 453         bw = bandwidths.select_bandwidth(X, bw, kern) # will cross-val fit this pattern?
#     454     bw *= adjust
#     455
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\statsmodels\nonparametric\bandwidths.py in select_bandwidth(x, bw, kernel)
#     172         # eventually this can fall back on another selection criterion.
#     173         err = "Selected KDE bandwidth is 0. Cannot estimate density."
# --> 174         raise RuntimeError(err)
#     175     else:
#     176         return bandwidth
#
# RuntimeError: Selected KDE bandwidth is 0. Cannot estimate density.

# %%
# Out:
# Year                 int64
# Month                int64
# Supplier            object
# ItemCode            object
# Description         object
# ItemType            object
# RetailSales        float64
# RetailTransfers    float64
# WarehouseSales     float64
# dtype: object

# %%
sns.pairplot(data=data, hue='ItemType')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-88137ef04a9a> in <module>
# ----> 1 sns.pairplot(data=data, hue='ItemType')
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2119             diag_kws.setdefault("shade", True)
#    2120             diag_kws["legend"] = False
# -> 2121             grid.map_diag(kdeplot, **diag_kws)
#    2122
#    2123     # Maybe plot on the off-diagonals
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1488                     data_k = utils.remove_na(data_k)
#    1489
# -> 1490                 func(data_k, label=label_k, color=color, **kwargs)
#    1491
#    1492             self._clean_axis(ax)
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     701                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     702     else:
# --> 703         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     704                                  gridsize, cut, clip, legend, ax,
#     705                                  cumulative=cumulative, **kwargs)
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     291     elif _has_statsmodels:
#     292         # Prefer using statsmodels for kernel flexibility
# --> 293         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     294                                            gridsize, cut, clip,
#     295                                            cumulative=cumulative)
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     365     fft = kernel == "gau"
#     366     kde = smnp.KDEUnivariate(data)
# --> 367     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     368     if cumulative:
#     369         grid, y = kde.support, kde.cdf
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     136                 msg = "Weights are not implemented for fft"
#     137                 raise NotImplementedError(msg)
# --> 138             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     139                     adjust=adjust, weights=weights, gridsize=gridsize,
#     140                     clip=clip, cut=cut)
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     451         bw = float(bw)
#     452     except:
# --> 453         bw = bandwidths.select_bandwidth(X, bw, kern) # will cross-val fit this pattern?
#     454     bw *= adjust
#     455
#
# c:\users\pedro\appdata\local\programs\python\python38\lib\site-packages\statsmodels\nonparametric\bandwidths.py in select_bandwidth(x, bw, kernel)
#     172         # eventually this can fall back on another selection criterion.
#     173         err = "Selected KDE bandwidth is 0. Cannot estimate density."
# --> 174         raise RuntimeError(err)
#     175     else:
#     176         return bandwidth
#
# RuntimeError: Selected KDE bandwidth is 0. Cannot estimate density.
