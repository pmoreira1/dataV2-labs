# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
population_data_url = 'http://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv'
covid_data = pd.read_csv('data/covid_19_data.csv')
population_data = pd.read_csv('downloads/API_SP.POP.TOTL_DS2_en_csv_v2_887275.csv')

# %%
# Grab only data for 2018
population_data = population_data[['Country Name', '2018']]
# Out:
#      Country Name        2018
# 0           Aruba    105845.0
# 1     Afghanistan  37172386.0
# 2          Angola  30809762.0
# 3         Albania   2866376.0
# 4         Andorra     77006.0
# ..            ...         ...
# 259        Kosovo   1845300.0
# 260   Yemen, Rep.  28498687.0
# 261  South Africa  57779622.0
# 262        Zambia  17351822.0
# 263      Zimbabwe  14439018.0
#
# [264 rows x 2 columns]

# %%
# Drop Na values since we will not be able to use them anyway
population_final.dropna(inplace=True)
# Out:
# <ipython-input-130-1626cc98704a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population_final.dropna(inplace=True)

# %%
# Rename a few columns
population_final.rename(columns={
        'Country Name': 'Country',
        '2018': 'Population'
    }, inplace=True)
# Convert data to int
population_final['Population'] = population_final['Population'].astype(int)
population_final
# Out:
# <ipython-input-138-19a7904b0315>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population_final['Population'] = population_final['Population'].astype(int)
#           Country  Population
# 0           Aruba      105845
# 1     Afghanistan    37172386
# 2          Angola    30809762
# 3         Albania     2866376
# 4         Andorra       77006
# ..            ...         ...
# 259        Kosovo     1845300
# 260   Yemen, Rep.    28498687
# 261  South Africa    57779622
# 262        Zambia    17351822
# 263      Zimbabwe    14439018
#
# [262 rows x 2 columns]

# %%
covid_data
# Out:
#       Unnamed: 0      Country RegisteredDate  Confirmed  Deaths  Recovered  \
# 0              0  Afghanistan     2020-02-24        1.0     0.0        0.0
# 1              1  Afghanistan     2020-02-25        1.0     0.0        0.0
# 2              2  Afghanistan     2020-02-26        1.0     0.0        0.0
# 3              3  Afghanistan     2020-02-27        1.0     0.0        0.0
# 4              4  Afghanistan     2020-02-28        1.0     0.0        0.0
# ...          ...          ...            ...        ...     ...        ...
# 4104        4104       Zambia     2020-03-23        3.0     0.0        0.0
# 4105        4105     Zimbabwe     2020-03-20        1.0     0.0        0.0
# 4106        4106     Zimbabwe     2020-03-21        3.0     0.0        0.0
# 4107        4107     Zimbabwe     2020-03-22        3.0     0.0        0.0
# 4108        4108     Zimbabwe     2020-03-23        3.0     1.0        0.0
#
#       Active
# 0        1.0
# 1        1.0
# 2        1.0
# ...

# %%
# Out:
#        Country RegisteredDate  Confirmed  Deaths  Recovered  Active
# 2787  Portugal     2020-03-02        2.0     0.0        0.0     2.0
# 2788  Portugal     2020-03-03        2.0     0.0        0.0     2.0
# 2789  Portugal     2020-03-04        5.0     0.0        0.0     5.0
# 2790  Portugal     2020-03-05        8.0     0.0        0.0     8.0
# 2791  Portugal     2020-03-06       13.0     0.0        0.0    13.0
# 2792  Portugal     2020-03-07       20.0     0.0        0.0    20.0
# 2793  Portugal     2020-03-08       30.0     0.0        0.0    30.0
# 2794  Portugal     2020-03-09       30.0     0.0        0.0    30.0
# 2795  Portugal     2020-03-10       41.0     0.0        0.0    41.0
# 2796  Portugal     2020-03-11       59.0     0.0        0.0    59.0
# 2797  Portugal     2020-03-12       59.0     0.0        0.0    59.0
# 2798  Portugal     2020-03-13      112.0     0.0        1.0   111.0
# 2799  Portugal     2020-03-14      169.0     0.0        2.0   167.0
# ...
